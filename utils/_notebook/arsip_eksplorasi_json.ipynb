# %%
import re
import json

# %%
data="""{\n "dataOrder": [\n {\n "nama_customer": "Muhammad Ridho Pratama",\n "jenis_barang": "kamera",\n "nama_barang": "Nikon D700",\n "jumlah_barang": 1,\n "estimasi_nilai_barang": 1931580\n }\n ]\n}"""

# %%
parsed_result = json.loads(data)

# %%
parsed_result['dataOrder']
# Out:
# [{'nama_customer': 'Muhammad Ridho Pratama',
#   'jenis_barang': 'kamera',
#   'nama_barang': 'Nikon D700',
#   'jumlah_barang': 1,
#   'estimasi_nilai_barang': 1931580}]

# %%
str(parsed_result)
# Out:
# "{'dataOrder': [{'nama_customer': 'Muhammad Ridho Pratama', 'jenis_barang': 'kamera', 'nama_barang': 'Nikon D700', 'jumlah_barang': 1, 'estimasi_nilai_barang': 1931580}]}"
